# %%
# Pandas
import pandas as pd

# %%
pd.read_csv('gapminder.csv')
# Out:
#     continent                   country  gdpPercap_1952  gdpPercap_1957  \
# 0      Africa                   Algeria     2449.008185     3013.976023
# 1      Africa                    Angola     3520.610273     3827.940465
# 2      Africa                     Benin     1062.752200      959.601080
# 3      Africa                  Botswana      851.241141      918.232535
# 4      Africa              Burkina Faso      543.255241      617.183465
# 5      Africa                   Burundi      339.296459      379.564628
# 6      Africa                  Cameroon     1172.667655     1313.048099
# 7      Africa  Central African Republic     1071.310713     1190.844328
# 8      Africa                      Chad     1178.665927     1308.495577
# 9      Africa                   Comoros     1102.990936     1211.148548
# 10     Africa           Congo Dem. Rep.      780.542326      905.860230
# 11     Africa                Congo Rep.     2125.621418     2315.056572
# ...

# %%
data = pd.read_csv('gapminder.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 38 columns):
# continent         142 non-null object
# country           142 non-null object
# gdpPercap_1952    142 non-null float64
# gdpPercap_1957    142 non-null float64
# gdpPercap_1962    142 non-null float64
# gdpPercap_1967    142 non-null float64
# gdpPercap_1972    142 non-null float64
# gdpPercap_1977    142 non-null float64
# gdpPercap_1982    142 non-null float64
# gdpPercap_1987    142 non-null float64
# gdpPercap_1992    142 non-null float64
# gdpPercap_1997    142 non-null float64
# gdpPercap_2002    142 non-null float64
# gdpPercap_2007    142 non-null float64
# lifeExp_1952      142 non-null float64
# lifeExp_1957      142 non-null float64
# lifeExp_1962      142 non-null float64
# lifeExp_1967      142 non-null float64
# lifeExp_1972      142 non-null float64
# lifeExp_1977      142 non-null float64
# lifeExp_1982      142 non-null float64
# ...

# %%
data.columns
# Out:
# Index(['continent', 'country', 'gdpPercap_1952', 'gdpPercap_1957',
#        'gdpPercap_1962', 'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977',
#        'gdpPercap_1982', 'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997',
#        'gdpPercap_2002', 'gdpPercap_2007', 'lifeExp_1952', 'lifeExp_1957',
#        'lifeExp_1962', 'lifeExp_1967', 'lifeExp_1972', 'lifeExp_1977',
#        'lifeExp_1982', 'lifeExp_1987', 'lifeExp_1992', 'lifeExp_1997',
#        'lifeExp_2002', 'lifeExp_2007', 'pop_1952', 'pop_1957', 'pop_1962',
#        'pop_1967', 'pop_1972', 'pop_1977', 'pop_1982', 'pop_1987', 'pop_1992',
#        'pop_1997', 'pop_2002', 'pop_2007'],
#       dtype='object')

# %%
for i in data.columns:
    print(i)
# Out:
# continent
# country
# gdpPercap_1952
# gdpPercap_1957
# gdpPercap_1962
# gdpPercap_1967
# gdpPercap_1972
# gdpPercap_1977
# gdpPercap_1982
# gdpPercap_1987
# gdpPercap_1992
# gdpPercap_1997
# gdpPercap_2002
# gdpPercap_2007
# lifeExp_1952
# lifeExp_1957
# lifeExp_1962
# lifeExp_1967
# lifeExp_1972
# lifeExp_1977
# lifeExp_1982
# lifeExp_1987
# lifeExp_1992
# lifeExp_1997
# lifeExp_2002
# lifeExp_2007
# pop_1952
# pop_1957
# pop_1962
# pop_1967
# pop_1972
# pop_1977
# pop_1982
# pop_1987
# pop_1992
# pop_1997
# pop_2002
# pop_2007

# %%
data.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count      142.000000      142.000000      142.000000      142.000000
# mean      3725.276046     4299.408345     4725.812342     5483.653047
# std       9321.064786     9869.662202     8667.362525     8095.315431
# min        298.846212      335.997115      355.203227      349.000000
# 25%        864.752389      930.540819     1059.149171     1151.245103
# 50%       1968.528344     2173.220291     2335.439533     2678.334741
# 75%       3913.492777     4876.356362     5709.381428     7075.932943
# max     108382.352900   113523.132900    95458.111760    80894.883260
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count      142.000000      142.000000      142.000000      142.000000
# mean      6770.082815     7313.166421     7518.901673     7900.920218
# std      10614.383403     8362.489150     7733.845006     8288.281304
# ...

# %%
data.loc[0, 'country']
# Out:
# 'Algeria'

# %%
data.loc[1, 'country']
# Out:
# 'Angola'

# %%
data.loc[0, :]
# Out:
# continent              Africa
# country               Algeria
# gdpPercap_1952        2449.01
# gdpPercap_1957        3013.98
# gdpPercap_1962        2550.82
# gdpPercap_1967        3246.99
# gdpPercap_1972        4182.66
# gdpPercap_1977        4910.42
# gdpPercap_1982        5745.16
# gdpPercap_1987        5681.36
# gdpPercap_1992        5023.22
# gdpPercap_1997         4797.3
# gdpPercap_2002        5288.04
# gdpPercap_2007        6223.37
# lifeExp_1952           43.077
# lifeExp_1957           45.685
# lifeExp_1962           48.303
# lifeExp_1967           51.407
# lifeExp_1972           54.518
# lifeExp_1977           58.014
# lifeExp_1982           61.368
# lifeExp_1987           65.799
# lifeExp_1992           67.744
# lifeExp_1997           69.152
# lifeExp_2002           70.994
# lifeExp_2007           72.301
# pop_1952          9.27952e+06
# pop_1957          1.02709e+07
# pop_1962          1.10009e+07
# pop_1967          1.27605e+07
# pop_1972          1.47608e+07
# ...

# %%
data.iloc[0, 0]  # To use index. Avoid it!
# Out:
# 'Africa'

# %%
data.loc[0, 'country']
# Out:
# 'Algeria'

# %%
# Exercise
# How do I select the first 5 rows
# and the columns 'continent', 'country'
# and 'gpdPercap_1952'
# Hint: We can use : so you shoud be able to use list
data.loc[
    [0, 1, 2, 3, 4],
    ['continent', 'country', 'gdpPercap_1952']
]
# Out:
#   continent       country  gdpPercap_1952
# 0    Africa       Algeria     2449.008185
# 1    Africa        Angola     3520.610273
# 2    Africa         Benin     1062.752200
# 3    Africa      Botswana      851.241141
# 4    Africa  Burkina Faso      543.255241

# %%
data.loc[
    0:4,
    ['continent', 'country', 'gdpPercap_1952']
]
# Out:
#   continent       country  gdpPercap_1952
# 0    Africa       Algeria     2449.008185
# 1    Africa        Angola     3520.610273
# 2    Africa         Benin     1062.752200
# 3    Africa      Botswana      851.241141
# 4    Africa  Burkina Faso      543.255241

# %%
data.loc[
    range(5),
    ['continent', 'country', 'gdpPercap_1952']
]
# Out:
#   continent       country  gdpPercap_1952
# 0    Africa       Algeria     2449.008185
# 1    Africa        Angola     3520.610273
# 2    Africa         Benin     1062.752200
# 3    Africa      Botswana      851.241141
# 4    Africa  Burkina Faso      543.255241

# %%
# Filtering
sample = data.loc[
    range(5),
    ['continent', 'country', 'gdpPercap_1952']
]

# %%
sample
# Out:
#   continent       country  gdpPercap_1952
# 0    Africa       Algeria     2449.008185
# 1    Africa        Angola     3520.610273
# 2    Africa         Benin     1062.752200
# 3    Africa      Botswana      851.241141
# 4    Africa  Burkina Faso      543.255241

# %%
sample.loc[:, 'country']
# Out:
# 0         Algeria
# 1          Angola
# 2           Benin
# 3        Botswana
# 4    Burkina Faso
# Name: country, dtype: object

# %%
sample.loc[:, 'country'] == 'Botswana'
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: country, dtype: bool

# %%
sample.loc[
    sample.loc[:, 'country'] == 'Botswana',
    :
]
# Out:
#   continent   country  gdpPercap_1952
# 3    Africa  Botswana      851.241141

# %%
botswana_sample = sample.loc[
    sample.loc[:, 'country'] == 'Botswana',
    :
]

# %%
botswana_sample
# Out:
#   continent   country  gdpPercap_1952
# 3    Africa  Botswana      851.241141

# %%
# Exercise
# Can you get from data,
# all the information about Botswana?
data.loc[
    data.loc[:, 'country'] == 'Botswana',
    :
]
# Out:
#   continent   country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 3    Africa  Botswana      851.241141      918.232535      983.653976
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 3     1214.709294     2263.611114     3214.857818      4551.14215
#
#    gdpPercap_1987  ...  pop_1962  pop_1967  pop_1972  pop_1977  pop_1982  \
# 3      6205.88385  ...  512764.0  553541.0  619351.0  781472.0  970347.0
#
#     pop_1987   pop_1992   pop_1997  pop_2002  pop_2007
# 3  1151184.0  1342614.0  1536536.0   1630347   1639131
#
# [1 rows x 38 columns]

# %%
# Exercise
# Can you get from data,
# all the information about Brazil?
data.loc[
    data.loc[:, 'country'] == 'Brazil',
    :
]
# Out:
#    continent country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 54  Americas  Brazil     2108.944355     2487.365989     3336.585802
#
#     gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 54     3429.864357     4985.711467     6660.118654     7030.835878
#
#     gdpPercap_1987  ...    pop_1962    pop_1967     pop_1972     pop_1977  \
# 54     7807.095818  ...  76039390.0  88049823.0  100840058.0  114313951.0
#
#        pop_1982     pop_1987     pop_1992     pop_1997   pop_2002   pop_2007
# 54  128962939.0  142938076.0  155975974.0  168546719.0  179914212  190010647
#
# [1 rows x 38 columns]

# %%
data.columns.str.startswith('gdpPercap')
# Out:
# array([False, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
gdp_botswana = data.loc[
    data.loc[:, 'country'] == 'Botswana',
    data.columns.str.startswith('gdpPercap')
]

# %%
gdp_botswana
# Out:
#    gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# 3      851.241141      918.232535      983.653976     1214.709294
#
#    gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# 3     2263.611114     3214.857818      4551.14215      6205.88385
#
#    gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# 3     7954.111645     8647.142313     11003.60508     12569.85177

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(
    gdp_botswana.loc[3, :]
)

# %%
new_names_columns = gdp_botswana.columns.str.strip('gdpPercap_')
gdp_botswana.columns = new_names_columns.astype(int)
gdp_botswana
# Out:
#          1952        1957        1962         1967         1972         1977  \
# 3  851.241141  918.232535  983.653976  1214.709294  2263.611114  3214.857818
#
#          1982        1987         1992         1997         2002         2007
# 3  4551.14215  6205.88385  7954.111645  8647.142313  11003.60508  12569.85177

# %%
gdp_botswana = gdp_botswana.reset_index(
    drop=True
)

# %%
plt.plot(
    gdp_botswana.loc[0, :]
)
